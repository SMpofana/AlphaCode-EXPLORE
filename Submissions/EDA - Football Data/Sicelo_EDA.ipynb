# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import pandas_profiling
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
Username='admin'
Password = 'amazing_people'
Host = 'alphacode-explore.ccwgqdqrrmvt.eu-west-1.rds.amazonaws.com'
Port='1433'
Database = 'Sicelo'

# %%
connection = create_engine(
    'mssql+pymssql://' + Username + ':' + Password + '@' + Host + ':' + Port + '/' + Database
    )

# %%
sql_query = 'SELECT * from football_players'

# %%
df=pd.read_sql_query(sql_query,connection)

# %%
df.head(3)
# Out:
#             Name Age Nationality Overall Acceleration Aggression Agility  \
# 0  G. Figliomeni  30       Italy  65           34         68      32
# 1      F. Melara  31       Italy  65           68         50      55
# 2       L. Ochoa  32    Colombia  65           67         66      70
#
#   Balance Ball control Composure  ... Short passing Shot power Sliding tackle  \
# 0  48           51        65      ...        53         49             65
# 1  34           68        65      ...        59         56             44
# 2  66           61        58      ...        62         70             64
#
#   Sprint speed Stamina Standing tackle Strength  Vision Volleys  \
# 0       32      53              66       74      41      28
# 1       67      67              46       81      62      49
# 2       69      65              66       60      56      40
#
#   Preferred Positions
# 0              RB CB
# 1       CAM LM RW RM
# 2                 RB
#
# [3 rows x 39 columns]

# %%
forwards=['ST', 'LW', 'RW']
forwards_pl=df[df['Preferred Positions'].str.contains('|'.join(forwards))]

# %%
forwards_pl['Acceleration'].mean()
# Out:
# 117.33955393718708

# %%
forwards_pl.count()
# Out:
# Name                   4419
# Age                    4419
# Nationality            4419
# Overall                4419
# Acceleration           4394
# Aggression             4419
# Agility                4419
# Balance                4419
# Ball control           4419
# Composure              4419
# Crossing               4419
# Curve                  4419
# Dribbling              4419
# Finishing              4419
# Free kick accuracy     4419
# GK diving              4419
# GK handling            4419
# GK kicking             4419
# GK positioning         4419
# GK reflexes            4419
# Heading accuracy       4419
# Interceptions          4419
# Jumping                4419
# Long passing           4419
# Long shots             4419
# Marking                4419
# Penalties              4419
# Positioning            4419
# Reactions              4395
# Short passing          4419
# Shot power             4419
# Sliding tackle         4419
# Sprint speed           4419
# ...

# %%
forwards_pl['Reactions'].mean()
# Out:
# 112.51695108077361

# %%
defenders=['LB','CB', 'RB']
defenders_pl=df[df['Preferred Positions'].str.contains('|'.join(defenders))]

# %%
defenders_pl.sort_values('Sliding tackle', ascending=False)
# Out:
#                        Name Age          Nationality  Overall Acceleration  \
# 202            Sergio Ramos  31                Spain       90       75
# 217              J. Boateng  28              Germany       88       72
# 219              M. Hummels  28              Germany       88       62
# 209            G. Chiellini  32                Italy       89       68
# 218               D. GodÃ­n  31              Uruguay       88       62
# 216              L. Bonucci  30                Italy       88       62
# 222            Thiago Silva  32               Brazil       88       70
# 283             A. Barzagli  36                Italy       85       64
# 661               S. Bender  28              Germany       80       67
# 297              K. Manolas  26               Greece       84       78
# 322             J. GimÃ©nez  22              Uruguay       83       68
# 231                 Marcelo  29               Brazil       87       77
# ...

# %%
defenders_pl.count()
# Out:
# Name                   6386
# Age                    6386
# Nationality            6386
# Overall                6386
# Acceleration           6386
# Aggression             6386
# Agility                6386
# Balance                6386
# Ball control           6386
# Composure              6386
# Crossing               6386
# Curve                  6386
# Dribbling              6386
# Finishing              6386
# Free kick accuracy     6386
# GK diving              6386
# GK handling            6386
# GK kicking             6386
# GK positioning         6386
# GK reflexes            6386
# Heading accuracy       6386
# Interceptions          6386
# Jumping                6386
# Long passing           6386
# Long shots             6386
# Marking                6386
# Penalties              6386
# Positioning            6386
# Reactions              6386
# Short passing          6386
# Shot power             6386
# Sliding tackle         6386
# Sprint speed           6386
# ...

# %%
goalkeeper=df[df['Preferred Positions'].str.contains('GK')]

# %%
goalkeeper.head(3)
# Out:
#           Name Age Nationality  Overall  Acceleration Aggression Agility  \
# 12  I. AustbÃ¸  32      Norway       65          21.0     42      50
# 13    T. Loska  21      Poland       65          36.0     17      35
# 17     M. Theo  36   Australia       65          51.0     35      54
#
#    Balance Ball control Composure  ... Short passing Shot power  \
# 12  47           18        49      ...        36         21
# 13  48           24        26      ...        32         20
# 17  50           14        40      ...        32         17
#
#    Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 12         22           31      31              13       84      56
# 13         13           38      23              14       65      25
# 17         14           52      39              13       56      56
#
#    Volleys Preferred Positions
# 12  14                     GK
# 13  20                     GK
# 17  14                     GK
#
# [3 rows x 39 columns]

# %%
goalkeeper.count()
# Out:
# Name                   2029
# Age                    2029
# Nationality            2029
# Overall                2029
# Acceleration           2028
# Aggression             2029
# Agility                2029
# Balance                2029
# Ball control           2029
# Composure              2029
# Crossing               2029
# Curve                  2029
# Dribbling              2029
# Finishing              2029
# Free kick accuracy     2029
# GK diving              2014
# GK handling            2012
# GK kicking             2018
# GK positioning         2029
# GK reflexes            2011
# Heading accuracy       2029
# Interceptions          2029
# Jumping                2029
# Long passing           2029
# Long shots             2029
# Marking                2029
# Penalties              2029
# Positioning            2029
# Reactions              2025
# Short passing          2029
# Shot power             2029
# Sliding tackle         2029
# Sprint speed           2029
# ...

# %%
mid=['CM','LM','RM','CAM','CDM']
mid_pl=df[df['Preferred Positions'].str.contains('|'.join(mid))]

# %%
mid_pl.count()
# Out:
# Name                   8521
# Age                    8521
# Nationality            8521
# Overall                8521
# Acceleration           8494
# Aggression             8521
# Agility                8521
# Balance                8521
# Ball control           8521
# Composure              8521
# Crossing               8521
# Curve                  8521
# Dribbling              8521
# Finishing              8521
# Free kick accuracy     8521
# GK diving              8521
# GK handling            8521
# GK kicking             8521
# GK positioning         8521
# GK reflexes            8521
# Heading accuracy       8521
# Interceptions          8521
# Jumping                8521
# Long passing           8521
# Long shots             8521
# Marking                8521
# Penalties              8521
# Positioning            8521
# Reactions              8484
# Short passing          8521
# Shot power             8521
# Sliding tackle         8521
# Sprint speed           8521
# ...

# %%
goalkeeper['GK reflexes'].mean()
# Out:
# 210.375435106912

# %%
goalkeeper['GK handling'].mean()
# Out:
# 180.79771371769382

# %%
goalkeeper['GK kicking'].mean()
# Out:
# 150.69276511397422

# %%
goalkeeper['GK diving'].mean()
# Out:
# 201.13008937437934

# %%
port=df['Nationality']=='Portugal'
port_pl=df.loc[port,:]

# %%
port_youth=port_pl[port_pl['Age']<25]

# %%
port_youth.sort_values('Overall',ascending=False)
# Out:
#                     Name  Age Nationality  Overall  Acceleration Aggression  \
# 286       Bernardo Silva   22    Portugal       84          85.0     58
# 325         JoÃ£o MÃ¡rio   24    Portugal       83          71.0     61
# 401         AndrÃ© Gomes   23    Portugal       82          71.0     81
# 492       NÃ©lson Semedo   23    Portugal       81          91.0     77
# 493       Gelson Martins   22    Portugal       81          95.0     57
# 503                Bruma   22    Portugal       81          94.0     64
# 507         R. Guerreiro   23    Portugal       81          83.0     69
# 596      Ricardo Pereira   23    Portugal       80          89.0     75
# 739        JoÃ£o Cancelo   23    Portugal       79          93.0     69
# 922        Iuri Medeiros   22    Portugal       78          84.0     67
# 1096     Bruno Fernandes   22    Portugal       78          79.0     62
# 1094                Rafa   24    Portugal       78          91.0     40
# ...

# %%
ENG=df['Nationality']=='England'
eng_epl=df.loc[ENG,:]

# %%
eng_epl.head()
# Out:
#                  Name Age Nationality  Overall Acceleration Aggression  \
# 4   A. Maitland-Niles  19     England       65       77         55
# 6            A. Grant  30     England       65       67         77
# 20            D. Ball  27     England       65       73         31
# 47          J. Akinde  27     England       64       77         70
# 88         R. Bennett  25     England       64       76         64
#
#    Agility Balance Ball control Composure  ... Short passing Shot power  \
# 4   74      70           63        55      ...        68         58
# 6   72      62           65        63      ...        66         58
# 20  80      61           66        60      ...        54         66
# 47  68      52           56        65      ...        46         64
# 88  58      66           55        57      ...        60         45
#
#    Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 4          58           72      72              59       68      60
# ...

# %%
eng_epl.groupby('Preferred Positions').count()
# Out:
#                      Name  Age  Nationality  Overall  Acceleration  \
# Preferred Positions
# CAM                    20   20           20       20            20
# CAM CDM CM              4    4            4        4             4
# CAM CM                 20   20           20       20            20
# CAM CM CDM              1    1            1        1             1
# CAM CM LM RM            1    1            1        1             1
# CAM CM RM               1    1            1        1             1
# CAM CM ST               1    1            1        1             1
# CAM LM                  8    8            8        8             8
# CAM LM CM               1    1            1        1             1
# CAM LM RM               3    3            3        3             3
# CAM LM RM CM            1    1            1        1             1
# CAM LM ST               2    2            2        2             2
# CAM LW LM               1    1            1        1             1
# ...

# %%
brazil=df['Nationality']=='Brazil'
brazil_pl=df.loc[brazil,:]

# %%
brazil_pl_gr=brazil_pl.groupby('Preferred Positions')

# %%
brazil_pl_gr.head(50)
# Out:
#                    Name Age Nationality  Overall Acceleration Aggression  \
# 62      Bernard Vicidal  29      Brazil       64       59         61
# 94            Tocantins  21      Brazil       64       73         41
# 154      Claudio Mouria  25      Brazil       64       58         43
# 194              Neymar  25      Brazil       92       94         56
# 222        Thiago Silva  32      Brazil       88       70         77
# 231             Marcelo  29      Brazil       87       77         84
# 243         Alex Sandro  26      Brazil       86       84         82
# 246            Coutinho  25      Brazil       86       88         55
# 249          David Luiz  30      Brazil       86       68         86
# 255             Miranda  32      Brazil       86       67         83
# 263            Casemiro  25      Brazil       85       63         87
# 281        Filipe LuÃ­s  31      Brazil       85       75         81
# ...

# %%
pl_national=df.groupby('Nationality', as_index=False).mean()

# %%
pl_national.sort_values('Overall', ascending=False)
# Out:
#              Nationality    Overall  Acceleration   Reactions
# 114                 Oman  73.000000     41.000000   76.000000
# 35                  Cuba  73.000000     82.500000   69.500000
# 146                Syria  72.500000     72.666667   67.500000
# 105           Mozambique  72.333333     71.666667   68.000000
# 64             Guatemala  72.000000     41.000000   63.000000
# 76                Israel  71.166667     67.083333   68.666667
# 150                 Togo  71.000000     79.250000   67.500000
# 47               Eritrea  71.000000     53.000000   74.000000
# 2                Algeria  70.947368     67.035088   65.456140
# 28                 Chile  70.896000     65.760000   68.530667
# 18                Brazil  70.895320    107.545006  124.246914
# 11               Belarus  70.777778     57.444444   63.666667
# 121             Portugal  70.599455     66.278689   67.969697
# 42               Ecuador  70.513514     70.945946   66.675676
# ...

# %%
df_Algeria=df['Nationality']=='Algeria'
algeria_pl=df.loc[df_Algeria,:]

# %%
list(df.columns)
# Out:
# ['Name',
#  'Age',
#  'Nationality',
#  'Overall',
#  'Acceleration',
#  'Aggression',
#  'Agility',
#  'Balance',
#  'Ball control',
#  'Composure',
#  'Crossing',
#  'Curve',
#  'Dribbling',
#  'Finishing',
#  'Free kick accuracy',
#  'GK diving',
#  'GK handling',
#  'GK kicking',
#  'GK positioning',
#  'GK reflexes',
#  'Heading accuracy',
#  'Interceptions',
#  'Jumping',
#  'Long passing',
#  'Long shots',
#  'Marking',
#  'Penalties',
#  'Positioning',
#  'Reactions',
#  'Short passing',
#  'Shot power',
#  'Sliding tackle',
#  'Sprint speed',
#  'Stamina',
#  'Standing tackle',
#  'Strength',
#  'Vision',
#  'Volleys',
#  'Preferred Positions']

# %%
algeria_pl.head()
# Out:
#              Name Age Nationality  Overall Acceleration Aggression Agility  \
# 108   Y. BelaÃ¯li  25     Algeria       64       73         42      68
# 335     R. Mahrez  26     Algeria       83       85         40      92
# 394    I. Slimani  29     Algeria       82       66         86      64
# 451    Y. Brahimi  27     Algeria       82       86         46      93
# 548  R. Boudebouz  27     Algeria       81       77         58      79
#
#     Balance Ball control Composure  ... Short passing Shot power  \
# 108  72           70        64      ...        48         62
# 335  85           88        82      ...        78         76
# 394  55           75        79      ...        73         78
# 451  87           85        86      ...        77         69
# 548  75           81        79      ...        83         79
#
#     Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 108         18           68      38              13       39      63
# ...

# %%
df_cb_backs=df['Preferred Positions']== 'CAM' 
df_cb_backs_pl=df.loc[df_cb_backs,:]

# %%
df_cb_backs_pl.count()
# Out:
# Name                   0
# Age                    0
# Nationality            0
# Overall                0
# Acceleration           0
# Aggression             0
# Agility                0
# Balance                0
# Ball control           0
# Composure              0
# Crossing               0
# Curve                  0
# Dribbling              0
# Finishing              0
# Free kick accuracy     0
# GK diving              0
# GK handling            0
# GK kicking             0
# GK positioning         0
# GK reflexes            0
# Heading accuracy       0
# Interceptions          0
# Jumping                0
# Long passing           0
# Long shots             0
# Marking                0
# Penalties              0
# Positioning            0
# Reactions              0
# Short passing          0
# Shot power             0
# Sliding tackle         0
# Sprint speed           0
# Stamina                0
# Standing tackle        0
# Strength               0
# Vision                 0
# ...
